# %%
# Ваша задача —
# научиться предсказывать результат более точно, чем ребята. Для этого был подготовлен
# датасет из нескольких траекторий корабля. Для каждого шага траектории имеются сле-
# дующие данные: состояние среды, действие агента и полученное вознаграждение. Вам
# необходимо предсказать резльутаты в тестовой выборке — справится ли агент с задачей,
# зная только текущее состояние среды. Задача считается решенной, если агент набрал за
# эпизод суммарную награду > 200. Cостояние кодируется 8 вещестенными числами.


# Решить задачу можно обучив классификатор (например нейросетевой) предсказывать
# могло ли данное состояние встречаться в эпизоде, для которого набрано суммарное воз-
# награждение хотя бы 200.
